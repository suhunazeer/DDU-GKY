# %% [markdown]
# # <center><u> Scaling on Car Sale dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=pd.read_csv('./Car_sales.csv')

# %%
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.Manufacturer.unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
data.Model.unique()
# Out:
# array(['Integra', 'TL', 'CL', 'RL', 'A4', 'A6', 'A8', '323i', '328i',
#        '528i', 'Century', 'Regal', 'Park Avenue', 'LeSabre', 'DeVille',
#        'Seville', 'Eldorado', 'Catera', 'Escalade', 'Cavalier', 'Malibu',
#        'Lumina', 'Monte Carlo', 'Camaro', 'Corvette', 'Prizm', 'Metro',
#        'Impala', 'Sebring Coupe', 'Sebring Conv.', 'Concorde', 'Cirrus',
#        'LHS', 'Town & Country', '300M', 'Neon', 'Avenger', 'Stratus',
#        'Intrepid', 'Viper', 'Ram Pickup', 'Ram Wagon', 'Ram Van',
#        'Dakota', 'Durango', 'Caravan', 'Escort', 'Mustang', 'Contour',
#        'Taurus', 'Focus', 'Crown Victoria', 'Explorer', 'Windstar',
#        'Expedition', 'Ranger', 'F-Series', 'Civic', 'Accord', 'CR-V',
#        'Passport', 'Odyssey', 'Accent', 'Elantra', 'Sonata', 'I30',
#        'S-Type', 'Wrangler', 'Cherokee', 'Grand Cherokee', 'ES300',
#        'GS300', 'GS400', 'LS400', 'LX470', 'RX300', 'Continental',
# ...

# %%
data.drop(columns={'Manufacturer','Model'},inplace=True)

# %%
data
# Out:
#      Sales_in_thousands  __year_resale_value Vehicle_type  Price_in_thousands  \
# 0                16.919               16.360    Passenger               21.50
# 1                39.384               19.875    Passenger               28.40
# 2                14.114               18.225    Passenger                 NaN
# 3                 8.588               29.725    Passenger               42.00
# 4                20.397               22.255    Passenger               23.99
# ..                  ...                  ...          ...                 ...
# 152               3.545                  NaN    Passenger               24.40
# 153              15.245                  NaN    Passenger               27.50
# 154              17.531                  NaN    Passenger               28.80
# 155               3.493                  NaN    Passenger               45.50
# 156              18.969                  NaN    Passenger               36.00
#
# ...

# %%
data.dropna(inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (117, 14)

# %%
data['VEH_TYPE'] = pd.get_dummies(data=data.Vehicle_type, drop_first=True)

# %%
data.head()
# Out:
#    Sales_in_thousands  __year_resale_value Vehicle_type  Price_in_thousands  \
# 0              16.919               16.360    Passenger               21.50
# 1              39.384               19.875    Passenger               28.40
# 3               8.588               29.725    Passenger               42.00
# 4              20.397               22.255    Passenger               23.99
# 5              18.780               23.555    Passenger               33.95
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
# 5          2.8       200.0      108.7   76.1   192.0        3.561
#
#    Fuel_capacity  Fuel_efficiency Latest_Launch  Power_perf_factor  VEH_TYPE
# ...

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, LabelEncoder

# %% [markdown]
# ### <li> Label Encoder

# %%
le = LabelEncoder()

# %%
data['VEHICLE_TYPE'] = le.fit_transform(data.Vehicle_type)

# %%
data
# Out:
#      Sales_in_thousands  __year_resale_value Vehicle_type  Price_in_thousands  \
# 0                16.919               16.360    Passenger               21.50
# 1                39.384               19.875    Passenger               28.40
# 3                 8.588               29.725    Passenger               42.00
# 4                20.397               22.255    Passenger               23.99
# 5                18.780               23.555    Passenger               33.95
# ..                  ...                  ...          ...                 ...
# 145               9.761               11.425    Passenger               14.90
# 146              83.721               13.240    Passenger               16.70
# 147              51.102               16.725    Passenger               21.20
# 148               9.569               16.575    Passenger               19.99
# 149               5.596               13.760    Passenger               17.50
#
# ...

# %% [markdown]
# ### Data Scaling or Data Normalising

# %% [markdown]
# ### <li><u> MinMax Scaler

# %%
minmax = MinMaxScaler()

# %%
data.Horsepower.max()
# Out:
# 450.0

# %%
data.Horsepower.min()
# Out:
# 55.0

# %%
data['HORSE_POWER'] = minmax.fit_transform(data[['Horsepower']].values)

# %%
data.head()
# Out:
#    Sales_in_thousands  __year_resale_value Vehicle_type  Price_in_thousands  \
# 0              16.919               16.360    Passenger               21.50
# 1              39.384               19.875    Passenger               28.40
# 3               8.588               29.725    Passenger               42.00
# 4              20.397               22.255    Passenger               23.99
# 5              18.780               23.555    Passenger               33.95
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
# 5          2.8       200.0      108.7   76.1   192.0        3.561
#
#    Fuel_capacity  Fuel_efficiency Latest_Launch  Power_perf_factor  VEH_TYPE  \
# ...

# %%
data.HORSE_POWER.min()
# Out:
# 0.0

# %%
data.HORSE_POWER.max()
# Out:
# 1.0

# %% [markdown]
# ### <li><u> Standard  Scaler

# %%
sc = StandardScaler()

# %%
data['HorsePower'] = sc.fit_transform(data[['Horsepower']].values)

# %%
data.head()
# Out:
#    Sales_in_thousands  __year_resale_value Vehicle_type  Price_in_thousands  \
# 0              16.919               16.360    Passenger               21.50
# 1              39.384               19.875    Passenger               28.40
# 3               8.588               29.725    Passenger               42.00
# 4              20.397               22.255    Passenger               23.99
# 5              18.780               23.555    Passenger               33.95
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
# 5          2.8       200.0      108.7   76.1   192.0        3.561
#
#    Fuel_capacity  Fuel_efficiency Latest_Launch  Power_perf_factor  VEH_TYPE  \
# ...
