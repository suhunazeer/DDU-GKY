# %% [markdown]
# # <center> <u> <font color='red'> EDA on Walmart Sales

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./walmart-sales-dataset-of-45stores.csv',parse_dates=['Date'])
data
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
data.shape
# Out:
# (6435, 8)

# %%
data.size
# Out:
# 51480

# %%
data.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
data.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
data.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
data.Holiday_Flag.value_counts()
# Out:
# 0    5985
# 1     450
# Name: Holiday_Flag, dtype: int64

# %%
data.nlargest(1,'Temperature')
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 4599     33 2010-07-16     280937.84             0       100.14       2.971
#
#              CPI  Unemployment
# 4599  126.149806         9.495

# %%
data.nlargest(1,'CPI')
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1286      9 2012-10-26     549731.49             0        69.52       3.506
#
#              CPI  Unemployment
# 1286  227.232807         4.954

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Histogram Plot

# %%
sns.histplot(data=data, x='Weekly_Sales', kde=True)
plt.title("Hist Plot- weekly sales")
plt.show()

# %%
sns.histplot(data=data, x='Temperature', kde=True)
plt.title("Hist Plot- Temperature")
plt.show()

# %%
sns.histplot(data=data, x='Fuel_Price', kde=True)
plt.title("Hist Plot- Fuel_Price")
plt.show()

# %% [markdown]
# ##### This plot is Bi-mode. That contains two mean

# %%
sns.histplot(data=data, x='CPI', kde=True)
plt.title("Hist Plot- CPI")
plt.show()

# %%
sns.histplot(data=data, x='Unemployment', kde=True)
plt.title("Hist Plot- Unemployment")
plt.show()

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(data=data, y='Weekly_Sales', color='violet')
plt.title("Box Plot - Weekly_Sales")
plt.show()

# %%
sns.boxplot(data=data, y='Temperature', color='blue')
plt.title("Box Plot - Temperature")
plt.show()

# %%
sns.boxplot(data=data, y='Fuel_Price', color='brown')
plt.title("Box Plot - Fuel_Price")
plt.show()

# %%
sns.boxplot(data=data, y='CPI', color='red')
plt.title("Box Plot - CPI")
plt.show()

# %%
sns.boxplot(data=data, y='Unemployment', color='green')
plt.title("Box Plot - Unemployment")
plt.show()

# %%
data.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-05-02    1643690.90             0        42.31       2.572
# 1      1 2010-12-02    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-05-03    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %% [markdown]
# #### Highest Weekly Sale

# %%
data.nlargest(5,'Weekly_Sales')
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1905     14 2010-12-24    3818686.45             0        30.59       3.141
# 2763     20 2010-12-24    3766687.43             0        25.17       3.141
# 1333     10 2010-12-24    3749057.69             0        57.06       3.236
# 527       4 2011-12-23    3676388.98             0        35.92       3.103
# 1762     13 2010-12-24    3595903.20             0        34.90       2.846
#
#              CPI  Unemployment
# 1905  182.544590         8.724
# 2763  204.637673         7.484
# 1333  126.983581         9.003
# 527   129.984548         5.143
# 1762  126.983581         7.795

# %% [markdown]
# ### Feature Engineering - Year, Month, Day Columns

# %%
data['Year']=data.Date.dt.year
data['Month']=data.Date.dt.month
data['Day']=data.Date.dt.day

# %%
data.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-05-02    1643690.90             0        42.31       2.572
# 1      1 2010-12-02    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-05-03    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Year  Month  Day
# 0  211.096358         8.106  2010      5    2
# 1  211.242170         8.106  2010     12    2
# 2  211.289143         8.106  2010      2   19
# 3  211.319643         8.106  2010      2   26
# 4  211.350143         8.106  2010      5    3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
#  8   Year          6435 non-null   int64
#  9   Month         6435 non-null   int64
#  10  Day           6435 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(5)
# memory usage: 553.1 KB

# %%
data.drop(columns='Date', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Weekly_Sales  6435 non-null   float64
#  2   Holiday_Flag  6435 non-null   int64
#  3   Temperature   6435 non-null   float64
#  4   Fuel_Price    6435 non-null   float64
#  5   CPI           6435 non-null   float64
#  6   Unemployment  6435 non-null   float64
#  7   Year          6435 non-null   int64
#  8   Month         6435 non-null   int64
#  9   Day           6435 non-null   int64
# dtypes: float64(5), int64(5)
# memory usage: 502.9 KB

# %% [markdown]
# ### Line Plot

# %%
data.Year.value_counts()
# Out:
# 2011    2340
# 2010    2160
# 2012    1935
# Name: Year, dtype: int64

# %% [markdown]
# ### Year wise filtering

# %%
data_2010=data.query("Year==2010")
data_2010
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6335     45     879244.90             0        40.93       3.046  182.667615
# 6336     45    1002364.34             0        30.54       3.109  182.551954
# 6337     45    1123282.85             0        30.51       3.140  182.517732
# 6338     45    1682862.03             0        30.59       3.141  182.544590
# 6339     45     679156.20             1        29.67       3.179  182.571448
#
#       Unemployment  Year  Month  Day
# ...

# %%
data_2011=data.query("Year==2011")
data_2011
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 48        1    1444732.28             0        48.27       2.976  211.404742
# 49        1    1391013.96             0        35.40       2.983  211.457411
# 50        1    1327405.42             0        44.04       3.016  211.827234
# 51        1    1316899.31             0        43.83       3.010  212.197058
# 52        1    1606629.58             0        42.27       2.989  212.566881
# ...     ...           ...           ...          ...         ...         ...
# 6387     45     875699.81             0        50.19       3.452  188.502435
# 6388     45     957155.31             0        46.57       3.415  188.654469
# 6389     45    1078905.68             0        39.93       3.413  188.797935
# 6390     45    1521957.99             0        42.27       3.389  188.929975
# 6391     45     869403.63             1        37.79       3.389  189.062016
#
#       Unemployment  Year  Month  Day
# ...

# %%
data_2012=data.query("Year==2012")
data_2012
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 100       1    1550369.92             0        49.01       3.157  219.714258
# 101       1    1459601.17             0        48.53       3.261  219.892526
# 102       1    1394393.84             0        54.11       3.268  219.985689
# 103       1    1319325.59             0        54.26       3.290  220.078852
# 104       1    1636339.65             0        56.55       3.360  220.172015
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  Year  Month  Day
# ...

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('Fuel_Price')
plt.title("Month wise Fuel_Price analysis")
sns.lineplot(data=data, x="Month", y='Fuel_Price',hue='Year')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('Weekly_Sales')
plt.title("Month wise Weekly_Sales analysis")
sns.lineplot(data=data, x="Month", y='Weekly_Sales',hue='Year')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('Temperature')
plt.title("Month wise Temperature analysis")
sns.lineplot(data=data, x="Month", y='Temperature',hue='Year')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('Unemployment')
plt.title("Month wise Unemployment analysis")
sns.lineplot(data=data, x="Month", y='Unemployment',hue='Year')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('CPI')
plt.title("Month wise CPI analysis")
sns.lineplot(data=data, x="Month", y='CPI',hue='Year')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('Weekly_Sales')
plt.title("2010 - Month wise weekly_sales analysis")
sns.lineplot(data=data_2010, x="Month", y='Weekly_Sales')
plt.show()

# %% [markdown]
# ##### Weekly sales rates are higher during December month of 2010

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('CPI')
plt.title("2010 - Month wise CPI analysis")
sns.lineplot(data=data_2010, x="Month", y='CPI')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('Unemployment')
plt.title("2010 - Month wise Unemployment analysis")
sns.lineplot(data=data_2010, x="Month", y='Unemployment')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('Temperature')
plt.title("2010 - Month wise Temperature analysis")
sns.lineplot(data=data_2010, x="Month", y='Temperature')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Month')
plt.ylabel('Fuel_Price')
plt.title("2010 - Month wise Fuel_Price analysis")
sns.lineplot(data=data_2010, x="Month", y='Fuel_Price')
plt.show()

# %% [markdown]
# ### Count Plot

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
plt.title("2010-Monthly sales based on holiday flg")
sns.countplot(data=data_2010, x='Month', hue='Holiday_Flag')
plt.show()

# %% [markdown]
# Holiday flags were available only during October to December of 2010. Among this December month had the highest flags

# %%
data_2010.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  Year  Month  Day
# 0         8.106  2010      5    2
# 1         8.106  2010     12    2
# 2         8.106  2010      2   19
# 3         8.106  2010      2   26
# 4         8.106  2010      5    3

# %% [markdown]
# ### Bar plot

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
plt.title("Barplot- Month wise weekly sales  analysis ")
sns.barplot(data=data, x="Month",y="Weekly_Sales")
plt.show()

# %% [markdown]
# <font color='blue'>December month have the highest weekly sales

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
plt.title("Barplot- Month wise Temperature  analysis ")
sns.barplot(data=data, x="Month",y="Temperature", hue='Year')
plt.show()

# %% [markdown]
# <font color='blue'>In 2010, Highest Temperature reported in June(temp in btw 75 and 80) , Lowest Temperature in December month(temp apprx=40)
#
# <font color='red'>In 2011,  Highest Temperature reported in August(temp in btw 70 &75), Lowest Temperature in November month(temp in btw 45 & 50 )
#
# <font color='green'>In 2012,  Highest Temperature reported in July(temp apprx=80 ), Lowest Temperature in February month(temp in btw 40 & 45 )

# %% [markdown]
# # Scatter plot

# %%
plt.title(" Relationship between Temperature and Fuel Price")
sns.scatterplot(data=data, x='Temperature', y='Fuel_Price', color='purple')
plt.show()

# %%
plt.title("Regression plot between temperature and fuel price")
sns.regplot(data=data, x='Temperature', y='Fuel_Price', color='magenta')
plt.show()

# %%
plt.title(" Relationship between Weekly sales and Fuel Price")
sns.scatterplot(data=data, x='Fuel_Price', y='Weekly_Sales', color='orange',hue="Year")
plt.show()

# %%
plt.title(" Regression analysis between Weekly sales and Fuel Price")
sns.regplot(data=data, x='Fuel_Price', y='Weekly_Sales', color='purple')
plt.show()

# %%
plt.title(" Relationship between CPI and Fuel Price")
sns.scatterplot(data=data, x='Fuel_Price', y='CPI', color='green', hue="Year")
plt.show()

# %%
plt.title(" Regression analysis between CPI and Fuel Price")
sns.regplot(data=data, x='Fuel_Price', y='CPI', color='green')
plt.show()

# %%
plt.title(" Regression analysis Unemployment and Weekly Sales")
sns.regplot(data=data, x='Unemployment', y='Weekly_Sales', color='indigo')
plt.show()

# %%
data.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  Year  Month  Day
# 0         8.106  2010      5    2
# 1         8.106  2010     12    2
# 2         8.106  2010      2   19
# 3         8.106  2010      2   26
# 4         8.106  2010      5    3

# %% [markdown]
# # Pie Chart

# %%
data.Year.value_counts().index
# Out:
# Int64Index([2011, 2010, 2012], dtype='int64')

# %%
palette_color=sns.color_palette('dar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\seaborn\palettes.py in color_palette(palette, n_colors, desat, as_cmap)
#     205                 # Perhaps a named matplotlib colormap?
# --> 206                 palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207             except ValueError:
#
# ~\anaconda3\lib\site-packages\seaborn\palettes.py in mpl_palette(name, n_colors, as_cmap)
#     442     else:
# --> 443         cmap = mpl.cm.get_cmap(name)
#     444
#
# ~\anaconda3\lib\site-packages\matplotlib\cm.py in get_cmap(name, lut)
#     285         return name
# --> 286     _api.check_in_list(sorted(_cmap_registry), name=name)
#     287     if lut is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py in check_in_list(_values, _print_supported_values, **kwargs)
# ...

# %%
palette_color=sns.color_palette('icefire')

# %%
plt.pie(data=data, x=data.Year.value_counts(), labels=[2011, 2010, 2012], explode=[0.1,0.1,0.1],
        colors=palette_color, autopct='%0.2f%%');

# %% [markdown]
# ### Holiday Sales

# %%
Holiday_Sales=data.groupby(['Holiday_Flag'])['Weekly_Sales'].mean()

# %%
Holiday_Sales
# Out:
# Holiday_Flag
# 0    1.041256e+06
# 1    1.122888e+06
# Name: Weekly_Sales, dtype: float64

# %%
Holiday_Sales.plot.pie(autopct='%1.2f%%',cmap='icefire');

# %% [markdown]
# ### Year Wise Sales

# %%
Year_Sales=data.groupby(['Year'])['Weekly_Sales'].sum()

# %%
Year_Sales
# Out:
# Year
# 2010    2.288886e+09
# 2011    2.448200e+09
# 2012    2.000133e+09
# Name: Weekly_Sales, dtype: float64

# %%
Year_Sales.plot.pie(autopct='%1.2f%%', cmap='coolwarm');

# %% [markdown]
# <font color='brown'>2011 has  highest sales

# %% [markdown]
# # Yearwise Unemployment

# %%
Unemployment_Year=data.groupby(['Year'])['Unemployment'].mean()

# %%
Unemployment_Year
# Out:
# Year
# 2010    8.492714
# 2011    8.082036
# 2012    7.347964
# Name: Unemployment, dtype: float64

# %%
Unemployment_Year.plot.pie(autopct='%1.2f%%', cmap='autumn');

# %% [markdown]
# <font color='blue'>Highest Unemployment rate was in the Year 2010 and unemployment gradually decreseas over years

# %% [markdown]
# ### Holiday Sales Over Years

# %%
Year_Holiday=data.groupby(['Year'])['Holiday_Flag'].sum()
Year_Holiday
# Out:
# Year
# 2010    180
# 2011    180
# 2012     90
# Name: Holiday_Flag, dtype: int64

# %%
Year_Holiday.plot.pie(autopct='%1.2f%%', cmap='summer');

# %%
data.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  Year  Month  Day
# 0         8.106  2010      5    2
# 1         8.106  2010     12    2
# 2         8.106  2010      2   19
# 3         8.106  2010      2   26
# 4         8.106  2010      5    3

# %%
data['Month']=data.Month.replace({1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',
                                  7:'July',8:'August',9:'September',10:'October',11:'November',
                                  12:'December'})

# %%
data.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  Year     Month  Day
# 0         8.106  2010       May    2
# 1         8.106  2010  December    2
# 2         8.106  2010  February   19
# 3         8.106  2010  February   26
# 4         8.106  2010       May    3
